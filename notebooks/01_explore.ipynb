# %%
from  import fetch_event
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from duv import fetch_event
#
# ModuleNotFoundError: No module named 'duv'

# %%
print("sdfsdfsdgf")
# Out:
# sdfsdfsdgf

# %%
2+3
# Out:
# 5
